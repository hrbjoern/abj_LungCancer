# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../data/dataseter.csv')

# %%
data.head()
# Out:
#   GENDER  AGE SMOKING YELLOW_FINGERS ANXIETY PEER_PRESSURE CHRONIC_DISEASE  \
# 0      M   65     Yes            Yes     Yes            No              No
# 1      F   55     Yes             No      No           Yes             Yes
# 2      F   78      No             No     Yes           Yes             Yes
# 3      M   60      No            Yes     Yes           Yes              No
# 4      F   80     Yes            Yes      No           Yes             Yes
#
#   FATIGUE ALLERGY WHEEZING ALCOHOL_CONSUMING COUGHING SHORTNESS_OF_BREATH  \
# 0     Yes      No       No                No       No                  No
# 1      No      No       No               Yes      Yes                 Yes
# 2      No     Yes       No               Yes      Yes                  No
# 3     Yes      No      Yes               Yes       No                 Yes
# 4      No     Yes       No               Yes      Yes                 Yes
#
#   SWALLOWING_DIFFICULTY CHEST_PAIN LUNG_CANCER
# ...

# %%
databin = pd.get_dummies(data, dtype=int)

databin.head()
# Out:
#    AGE  GENDER_F  GENDER_M  SMOKING_No  SMOKING_Yes  YELLOW_FINGERS_No  \
# 0   65         0         1           0            1                  0
# 1   55         1         0           0            1                  1
# 2   78         1         0           1            0                  1
# 3   60         0         1           1            0                  0
# 4   80         1         0           0            1                  0
#
#    YELLOW_FINGERS_Yes  ANXIETY_No  ANXIETY_Yes  PEER_PRESSURE_No  ...  \
# 0                   1           0            1                 1  ...
# 1                   0           1            0                 0  ...
# 2                   0           0            1                 0  ...
# 3                   1           0            1                 0  ...
# 4                   1           1            0                 0  ...
#
#    COUGHING_No  COUGHING_Yes  SHORTNESS_OF_BREATH_No  SHORTNESS_OF_BREATH_Yes  \
# ...

# %%
databin.describe()
# Out:
#                AGE     GENDER_F     GENDER_M   SMOKING_No  SMOKING_Yes  \
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean     55.169000     0.495333     0.504667     0.491000     0.509000
# std      14.723746     0.500062     0.500062     0.500002     0.500002
# min      30.000000     0.000000     0.000000     0.000000     0.000000
# 25%      42.000000     0.000000     0.000000     0.000000     0.000000
# 50%      55.000000     0.000000     1.000000     0.000000     1.000000
# 75%      68.000000     1.000000     1.000000     1.000000     1.000000
# max      80.000000     1.000000     1.000000     1.000000     1.000000
#
#        YELLOW_FINGERS_No  YELLOW_FINGERS_Yes   ANXIETY_No  ANXIETY_Yes  \
# count        3000.000000         3000.000000  3000.000000  3000.000000
# mean            0.514000            0.486000     0.494000     0.506000
# std             0.499887            0.499887     0.500047     0.500047
# ...
